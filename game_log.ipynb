# %%
import pandas as pd
from nba_api.stats.endpoints import teamgamelog
import time
import random
from team_games import get_team_log
# Out:
# /Users/bormilan/Documents/GitHub/nba/team_games.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_stats.loc[len(train_stats), ['W', 'L', 'W_PCT']] = 0, 0, 0

# %%
df = pd.read_csv('league_games.csv')
df.head()
# Out:
#    Unnamed: 0  SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 0           0      22022  1610612755               PHI     Philadelphia 76ers
# 1           1      22022  1610612744               GSW  Golden State Warriors
# 2           2      22022  1610612745               HOU        Houston Rockets
# 3           3      22022  1610612751               BKN          Brooklyn Nets
# 4           4      22022  1610612754               IND         Indiana Pacers
#
#     GAME_ID   GAME_DATE      MATCHUP WL  MIN  ...  DREB_2  REB_2  AST_2  \
# 0  22200001  2022-10-18    PHI @ BOS  A  240  ...      30     36     24
# 1  22200002  2022-10-18  GSW vs. LAL  H  240  ...      39     48     23
# 2  22200005  2022-10-19    HOU @ ATL  A  240  ...      32     43     27
# 3  22200006  2022-10-19  BKN vs. NOP  A  240  ...      39     53     21
# 4  22200004  2022-10-19  IND vs. WAS  A  240  ...      37     41     27
#
# ...

# %%
df_filtered = df[['SEASON_ID', 'GAME_ID', 'GAME_DATE', 'TEAM_ID', 'TEAM_NAME', 'TEAM_ID_2', 'TEAM_NAME_2']]

# %%
df_filtered.head()
# Out:
#    SEASON_ID   GAME_ID   GAME_DATE     TEAM_ID              TEAM_NAME  \
# 0      22022  22200001  2022-10-18  1610612755     Philadelphia 76ers
# 1      22022  22200002  2022-10-18  1610612744  Golden State Warriors
# 2      22022  22200005  2022-10-19  1610612745        Houston Rockets
# 3      22022  22200006  2022-10-19  1610612751          Brooklyn Nets
# 4      22022  22200004  2022-10-19  1610612754         Indiana Pacers
#
#     TEAM_ID_2         TEAM_NAME_2
# 0  1610612738      Boston Celtics
# 1  1610612747  Los Angeles Lakers
# 2  1610612762           Utah Jazz
# 3  1610612764  Washington Wizards
# 4  1610612758    Sacramento Kings

# %%
def get_team_WL(row):
    time.sleep(random.uniform(0.5,1))
    df1 = get_team_log(row["TEAM_NAME"])
    df2 = get_team_log(row["TEAM_NAME_2"])
    print(row["TEAM_NAME_2"])
    wl1 = df1.loc[df1['Game_ID'] == ("00" + str(row["GAME_ID"])), ['W', 'L', "W_PCT", "MATCHUP"]].values[0]
    print(df2.loc[df2['Game_ID'] == ("00" + str(row["GAME_ID"])), ['W', 'L', "W_PCT"]].values)
    wl2 = df2.loc[df2['Game_ID'] == ("00" + str(row["GAME_ID"])), ['W', 'L', "W_PCT"]].values[0]
    row["W_H"], row["L_H"], row["W_A"], row["L_A"],row["WPCT_H"], row["WPCT_A"], row["MATCHUP"] = wl1[0], wl2[1], wl2[0], wl2[1], wl1[2], wl2[2], wl1[3]
    return row

# %%
df_added = df_filtered.apply(get_team_WL, axis=1)
# Out:
# [[0. 0. 0.]]
# [[0. 0. 0.]]
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /Users/bormilan/Documents/GitHub/nba/game_log.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/bormilan/Documents/GitHub/nba/game_log.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> df_added = df_filtered.apply(get_team_WL, axis=1)
#
# File ~/.local/share/virtualenvs/nba--Czl-t1p/lib/python3.10/site-packages/pandas/core/frame.py:8845, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    8834 from pandas.core.apply import frame_apply
#    8836 op = frame_apply(
#    8837     self,
#    8838     func=func,
#    (...)
#    8843     kwargs=kwargs,
#    8844 )
# -> 8845 return op.apply().__finalize__(self, method="apply")
#
# File ~/.local/share/virtualenvs/nba--Czl-t1p/lib/python3.10/site-packages/pandas/core/apply.py:733, in FrameApply.apply(self)
# ...

# %%
df_added
# Out:
#      SEASON_ID   GAME_ID   GAME_DATE     TEAM_ID              TEAM_NAME  \
# 0        22022  22200002  2022-10-18  1610612747     Los Angeles Lakers
# 1        22022  22200001  2022-10-18  1610612755     Philadelphia 76ers
# 2        22022  22200012  2022-10-19  1610612762              Utah Jazz
# 3        22022  22200013  2022-10-19  1610612756           Phoenix Suns
# 4        22022  22200014  2022-10-19  1610612758       Sacramento Kings
# ..         ...       ...         ...         ...                    ...
# 178      22022  22200179  2022-11-11  1610612761        Toronto Raptors
# 179      22022  22200180  2022-11-11  1610612759      San Antonio Spurs
# 180      22022  22200181  2022-11-11  1610612763      Memphis Grizzlies
# 181      22022  22200183  2022-11-11  1610612758       Sacramento Kings
# 182      22022  22200182  2022-11-11  1610612744  Golden State Warriors
#
#       TEAM_ID_2             TEAM_NAME_2  W_H  L_H   W_A  L_A  WPCT_H  WPCT_A  \
# ...
